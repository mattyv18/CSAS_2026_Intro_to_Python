# %% [markdown]
# #1. Message Decoding
# Given a string of characters containing multiple words seperated by `z`, find the hidden message by replacing each instance of `2` with `a`, each instance of `?` with `e`, and each instance of `7` with `i`. Then split the string and combine the words again to form the hidden message.

# %%
"Izw2ntztozb?zk7ngzofzth?zp7r2t?s!"
# Out:
# 'Izw2ntztozb?zk7ngzofzth?zp7r2t?s!'

# %% [markdown]
# #2. Find My Date of Birth
#
# Given a scentece, find my date of birth by counting the number of a's to equal my month of birth, counting and summing the number of i's and e's and to equal my day of birth and then counting and summing the number of t's and f's and adding 2000 to equal my year of birth. Then print my birthday using f string.

# %%
"A cicada added acid, did a deft edit, and cited a fine idea see be."

# %% [markdown]
# # 3. Sort Without Using sorted() or .sort()
# Given the list, create a sorted list `y` without using the sorted() or .sort() function then append the elements of list `y` to list `x` as string type elements. Hint: Use str() to convert elements to string type.

# %%
x = [2,1,4,3,6,5]

# %% [markdown]
# # 4. Basketball Preformance Score
# Define a function `preform_score` that returns the preformance score of a basketball player based on there points, rebounds and assists.
#
# The formula to compute a preformance score is:
#
#
# *   `score` = `points` + 1.2 * `rebounds` + 1.5 * `assists`

# %%
def preform_score():

  return

# %% [markdown]
# #5. Hockey Stats
# Create a class that stores a given Hockey Teams name, total goals, total shots and games played. Then have the class contain 2 functions, one that calculates goals per game, and another that calculates scoring efficiency(% of shots taken that the team has scored).

# %%
class hockey_stats():
  pass

# %% [markdown]
# #6. Find Max Value of List
# Create an Algorithm that finds the max value of a given list without using max().

# %%
x = [10, 39, 40, 16, 20, 7, 18, 205, 1223, 128, 1020, 1442, 1230, 1302, 12, 123, 233, 442, 1000]

# %% [markdown]
# #Installing and importing packages
# 1. Use pip to install requests (in Jupyter Notebooks, you need ! at the start of a line to run terminal commands)
# 2. Import requests and make a GET request to the following API: https://dummyjson.com/products
# 3. Print the status code of the response
# 4. Print the content of the response
# 5. Print the content of the response as JSON
# Feel free to start searching to get your answers!
